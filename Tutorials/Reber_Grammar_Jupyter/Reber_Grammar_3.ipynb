# %% [markdown]
# # Learning on Reber-Grammar

# %% [markdown]
# ## Importing Libraries:

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM, TimeDistributed, Masking
from keras.optimizers import RMSprop
from keras.utils import np_utils
import numpy as np
import reber_utility as ru
# Out:
# Using Theano backend.

# %% [markdown]
# define important parameters:

# %%
step_size = 50
n_step=2

batch_size = 10
n_batch = 15 # total number of batches
n_test_batch = 2 # testing part

train_idxes = np.array(range(0,(n_batch-n_test_batch)*batch_size))
test_idxes = np.array(range((n_batch-n_test_batch)*batch_size, n_batch*batch_size))

N_Epoch = 80

# %% [markdown]
# generate and vectorize data to learn on:

# %%
m = ru.generate_reber_machine_continuous()

X,Y = m.to_X_and_Y(m.make_words(n_batch*batch_size,min_steps=(step_size*n_step+1)))

# %% [markdown]
# X and Y are the input and ouput data. Basically Y corresponds to X but shifted by one time-step (since we always want to predict the next time-step)

# %%
print X.shape
print Y.shape
# Out:
# (150, 100, 8)
# (150, 100, 8)

# %% [markdown]
# ## Building the model
# "Heart" of Keras: defining the layers of the sequential model. Our model contains the following layers:
# 1. Masking Layer: important if we want to deal with different sized input data
# 2. LSTM Layer: contains 20 units; return_sequences = True in order to make predicitions at each timestep; stateful = True in order to keep state during training
# 3. Dropout Layer: prevents model from overfitting
# 4. Timedistributed Dense: fully connected layer to reduce LSTM layer dimensionality to output size (number of letters)
# 5. Activation Layer: use sigmoid activation function to return probabilities (values between 0 and 1)
#
# Then we specify the optimizion algorithm for learning. In this case we use RMSprop with a learning rate of 0.01.
#
# Finally we can compile our model and specify the loss function as well as some metrics we want to investigate during training

# %%
model = Sequential()
model.add(Masking(mask_value= -1., batch_input_shape=(batch_size,step_size,len(m.transitions))))
model.add(LSTM(20, return_sequences=True,stateful=True, batch_input_shape=(batch_size,step_size,len(m.transitions))))
model.add(Dropout(0.2))
model.add(TimeDistributed(Dense(len(m.transitions))))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])

# %% [markdown]
# ## Train model
# train model and generate test / train metrics

# %%
metrics_train = np.zeros((N_Epoch,len(model.metrics_names),n_batch-n_test_batch))
metrics_test = np.zeros((N_Epoch,len(model.metrics_names),n_test_batch))

print('Starting to learn:')
for i in range(N_Epoch):
    print('------- {} out of {} Epoch -----'.format(i+1,N_Epoch))

    ## Epochs should take all data; batches presented random, reset at each end of batch_size
    np.random.shuffle(train_idxes)
    batches_idxes = np.reshape(train_idxes, (-1,batch_size))
    for j, batch  in enumerate(batches_idxes):
        #print('batch {} of {}'.format(j+1,n_batch-n_test_batch))
        for k in range(n_step):
            metrics_train[i,:,j] += model.train_on_batch(X[batch,k*step_size:(k+1)*(step_size)], Y[batch,k*step_size:(k+1)*step_size]) #python 0:3 gives 0,1,2 (which is not intuitive at all)
        model.reset_states() 

    test_batch_idxes = np.reshape(test_idxes,(-1,batch_size))
    for j, test_batch in enumerate(test_batch_idxes):
        for k in range(n_step):
                metrics_test[i,:,j] += model.test_on_batch(X[test_batch,k*step_size:(k+1)*(step_size)], Y[test_batch,k*step_size:(k+1)*step_size])
        model.reset_states() 

    metrics_test[i] = metrics_test[i]/float(n_step) # divide only i indice, else division would be done for all at each epoch
    metrics_train[i] = metrics_train[i]/float(n_step)

    print('Train results:\t {} \n \t {}'.format(model.metrics_names, np.mean(metrics_train[i],axis=1)))
    print('Test results:\t {} \n \t {}'.format(model.metrics_names, np.mean(metrics_test[i],axis=1) ))
# Out:
# Starting to learn:
# ------- 1 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 1.75470665  0.342     ]
# Test results:	 ['loss', 'acc']
#  	 [ 1.45743048  0.44800001]
# ------- 2 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 1.37409728  0.48215384]
# Test results:	 ['loss', 'acc']
#  	 [ 1.19803303  0.56850001]
# ------- 3 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 1.16663097  0.54307693]
# Test results:	 ['loss', 'acc']
#  	 [ 0.99294922  0.595     ]
# ------- 4 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.97576591  0.58746154]
# Test results:	 ['loss', 'acc']
#  	 [ 0.79899043  0.62800002]
# ------- 5 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.79715753  0.64623076]
# Test results:	 ['loss', 'acc']
#  	 [ 0.6583136  0.676    ]
# ------- 6 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.68330992  0.67469232]
# Test results:	 ['loss', 'acc']
#  	 [ 0.58119631  0.68399999]
# ------- 7 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.60399614  0.6833077 ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.52512991  0.69150001]
# ------- 8 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.55550423  0.68784614]
# Test results:	 ['loss', 'acc']
#  	 [ 0.50987914  0.67300004]
# ------- 9 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.52332538  0.69423076]
# Test results:	 ['loss', 'acc']
#  	 [ 0.48241764  0.68000001]
# ------- 10 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.51050347  0.68738462]
# Test results:	 ['loss', 'acc']
#  	 [ 0.47127442  0.67949998]
# ------- 11 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.49264651  0.6966923 ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.46757106  0.678     ]
# ------- 12 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.4863355   0.69392307]
# Test results:	 ['loss', 'acc']
#  	 [ 0.46527968  0.67650002]
# ------- 13 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.48032443  0.68553847]
# Test results:	 ['loss', 'acc']
#  	 [ 0.45460545  0.69099998]
# ------- 14 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.47644198  0.68900001]
# Test results:	 ['loss', 'acc']
#  	 [ 0.44755782  0.6925    ]
# ------- 15 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.47298393  0.694     ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.44732898  0.6925    ]
# ------- 16 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.46626021  0.6986154 ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.45487082  0.6875    ]
# ------- 17 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.46558212  0.69076923]
# Test results:	 ['loss', 'acc']
#  	 [ 0.44387113  0.70049998]
# ------- 18 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.46217484  0.69115385]
# Test results:	 ['loss', 'acc']
#  	 [ 0.44661553  0.70099998]
# ------- 19 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.4620309   0.69684615]
# Test results:	 ['loss', 'acc']
#  	 [ 0.44191067  0.69849998]
# ------- 20 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.45604636  0.69692307]
# Test results:	 ['loss', 'acc']
#  	 [ 0.4424547   0.69949999]
# ------- 21 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.45626258  0.69838461]
# Test results:	 ['loss', 'acc']
#  	 [ 0.44621688  0.69049999]
# ------- 22 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.45365709  0.70053846]
# Test results:	 ['loss', 'acc']
#  	 [ 0.43721332  0.70549998]
# ------- 23 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.44878627  0.71038461]
# Test results:	 ['loss', 'acc']
#  	 [ 0.42944334  0.72450003]
# ------- 24 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.44657031  0.7063077 ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.41926238  0.72      ]
# ------- 25 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.4338842   0.72015385]
# Test results:	 ['loss', 'acc']
#  	 [ 0.40133339  0.74349999]
# ------- 26 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.41445313  0.73307693]
# Test results:	 ['loss', 'acc']
#  	 [ 0.40970682  0.73050004]
# ------- 27 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.42693378  0.72623078]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39464438  0.73600003]
# ------- 28 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.41018351  0.72661539]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39700179  0.74149999]
# ------- 29 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.41995621  0.7233077 ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39638673  0.73700002]
# ------- 30 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40634102  0.73146154]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39408344  0.73000002]
# ------- 31 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40530002  0.72769233]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39620857  0.72499999]
# ------- 32 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.41796712  0.72407692]
# Test results:	 ['loss', 'acc']
#  	 [ 0.3913319   0.73800001]
# ------- 33 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40138147  0.72900001]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39409627  0.72800002]
# ------- 34 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40265204  0.73553846]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39194353  0.73400003]
# ------- 35 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40661325  0.73      ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.41470802  0.73349997]
# ------- 36 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40402489  0.73138463]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39236523  0.73549998]
# ------- 37 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.399532    0.73230769]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38894494  0.74200001]
# ------- 38 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39970646  0.73207693]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38867536  0.74900001]
# ------- 39 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40029125  0.73192309]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39328952  0.73999998]
# ------- 40 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39931915  0.73261538]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38903829  0.73900002]
# ------- 41 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40285841  0.72846155]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38789785  0.74250001]
# ------- 42 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39856261  0.72738462]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38755213  0.74900001]
# ------- 43 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39739715  0.73738463]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38712536  0.74300003]
# ------- 44 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39732669  0.73246155]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39127424  0.73550001]
# ------- 45 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40685343  0.73400001]
# Test results:	 ['loss', 'acc']
#  	 [ 0.3890865   0.73600003]
# ------- 46 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.3962326   0.72869231]
# Test results:	 ['loss', 'acc']
#  	 [ 0.39004086  0.74250001]
# ------- 47 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39459444  0.73123076]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38656975  0.73300001]
# ------- 48 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39542386  0.73361539]
# Test results:	 ['loss', 'acc']
#  	 [ 0.42009248  0.715     ]
# ------- 49 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39623022  0.73807693]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38789479  0.72850004]
# ------- 50 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39410229  0.73269233]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38482293  0.74150002]
# ------- 51 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40039304  0.72946154]
# Test results:	 ['loss', 'acc']
#  	 [ 0.423995    0.71050003]
# ------- 52 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39771781  0.73515385]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38684294  0.7385    ]
# ------- 53 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39269006  0.73553848]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38652986  0.73800004]
# ------- 54 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39320106  0.73100001]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38684799  0.72800002]
# ------- 55 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39408474  0.72953848]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38499948  0.743     ]
# ------- 56 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39318943  0.73484617]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38602532  0.73000002]
# ------- 57 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39167243  0.73353847]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38881311  0.72850001]
# ------- 58 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39087146  0.73384615]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38414256  0.73500001]
# ------- 59 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39383398  0.73338464]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38609362  0.73200002]
# ------- 60 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.3932171  0.733    ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38457587  0.74000001]
# ------- 61 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39131378  0.73238462]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38760491  0.73300001]
# ------- 62 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38976576  0.73876923]
# Test results:	 ['loss', 'acc']
#  	 [ 0.3874196   0.75199997]
# ------- 63 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.40192521  0.73369232]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38724644  0.72750002]
# ------- 64 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39117618  0.73438463]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38402382  0.73299998]
# ------- 65 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38972118  0.74038462]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38699003  0.72750002]
# ------- 66 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39129657  0.73569231]
# Test results:	 ['loss', 'acc']
#  	 [ 0.3856774   0.73800001]
# ------- 67 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38862575  0.74200001]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38650917  0.73550001]
# ------- 68 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38886777  0.73800001]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38797571  0.73550001]
# ------- 69 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39995345  0.73361538]
# Test results:	 ['loss', 'acc']
#  	 [ 0.3835171  0.7405   ]
# ------- 70 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38833203  0.73484617]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38531244  0.73100004]
# ------- 71 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38824934  0.73415386]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38692731  0.72899997]
# ------- 72 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39020486  0.73492308]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38574657  0.73300001]
# ------- 73 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38972022  0.73553847]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38714914  0.72850004]
# ------- 74 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38891067  0.73615385]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38397264  0.736     ]
# ------- 75 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38810379  0.73546154]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38817413  0.73199999]
# ------- 76 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39022764  0.7366154 ]
# Test results:	 ['loss', 'acc']
#  	 [ 0.48792168  0.70149997]
# ------- 77 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.39641313  0.73546155]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38448305  0.72650003]
# ------- 78 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38729562  0.73607693]
# Test results:	 ['loss', 'acc']
#  	 [ 0.3856843   0.73199999]
# ------- 79 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.38734256  0.73769231]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38542576  0.73000002]
# ------- 80 out of 80 Epoch -----
# Train results:	 ['loss', 'acc']
#  	 [ 0.386905   0.7366923]
# Test results:	 ['loss', 'acc']
#  	 [ 0.38420865  0.73700002]

# %% [markdown]
# ... and finally don't forget to save everything ;)

# %%
model.save('embedCerg_model_4.h5')
np.save('embedXdata_4.npy',X)
np.save('embedydata_4.npy',Y)
np.save('embedTrainMetrics_4', metrics_train)
np.save('embedTestMetrics_4', metrics_test)
